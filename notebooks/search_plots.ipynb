# %%
import torch
import matplotlib.pyplot as plt

# %%
data
# Out:
# [{'site_id': 'encoder_decoder.qe_qd',
#   'generation_indices': [0, 1, 2, 3, 4, 5, 6, 7],
#   'best_scores': [6.577743947505951,
#    6.577743947505951,
#    6.577743947505951,
#    5.740459978580475,
#    5.740459978580475,
#    5.740459978580475,
#    5.696999192237854,
#    5.507083892822266],
#   'committed_score': 5.507083892822266}]

# %%
site_num = 0
data = torch.load("/home/blessedg/asrq/outputs/rotation/openai-whisper-large-v3_rotation_w4a8_global_qe_qd_search_global_search_history.pt")
plt.plot(data[site_num]['best_scores'])
plt.xlabel("generations")
plt.ylabel("best fitness")
plt.title("whisper")
# Out:
# Text(0.5, 1.0, 'whisper')

# %%
data
# Out:
# [{'site_id': 'encoder_decoder.qe_qd',
#   'generation_indices': [0, 1, 2, 3, 4, 5, 6, 7],
#   'best_scores': [6.577743947505951,
#    6.577743947505951,
#    6.577743947505951,
#    5.740459978580475,
#    5.740459978580475,
#    5.740459978580475,
#    5.696999192237854,
#    5.507083892822266],
#   'committed_score': 5.507083892822266}]

# %%
datasite_num = 0
data = torch.load("/home/blessedg/asrq/outputs/rotation/parakeet_globalqe_global_search_history.pt")
plt.plot(data[site_num]['best_scores'])
plt.xlabel("generations")
plt.ylabel("best fitness")
plt.title("parakeet")
# Out:
# Text(0.5, 1.0, 'parakeet')

# %%
data
# Out:
# [{'site_id': 'encoder.qe',
#   'generation_indices': [0, 1, 2, 3, 4, 5],
#   'best_scores': [0.07380616944283247,
#    0.07328199129551649,
#    0.07508976338431239,
#    0.07426596898585558,
#    0.07550514116883278,
#    0.07367149321362376],
#   'committed_score': 0.07328199129551649}]
